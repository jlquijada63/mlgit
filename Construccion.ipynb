# %% [markdown]
# # Construccion del DataFrame

# %% [markdown]
# Los DataFrames de pandas pueden construirse de dos formas:
# 1. **Constructor**: `pd.DataFrame()`, que recibe como parametro una secuencia y otros parametros adicionales como el nombre de las columnas, la columna que se utiliza de indice etc.
# 2. **Importacion de archivos**: Esta es la forma mas frecuente en la practica real. Pandas tiene funciones para importar diferentes tipos de archivos. Los mas frecuentes son archivos del tipo .csv

# %% [markdown]
# ## Creación con el constructor

# %%
import pandas as pd
import numpy as np

# %%
cls = 'manzanas naranjas peras melocotones'
df = pd.DataFrame(np.reshape(np.arange(80),(20,4)),columns=cls.split())

# %%
df.head()
# Out:
#    manzanas  naranjas  peras  melocotones
# 0         0         1      2            3
# 1         4         5      6            7
# 2         8         9     10           11
# 3        12        13     14           15
# 4        16        17     18           19

# %% [markdown]
# ## Importacion a partir de un archivo

# %% [markdown]
# Es conveniente en primer lugar echar un vistazo a la estructura del archivo. Esto podemos hacer a traves de una llamada al sistema operativo (para ello se utiliza '!'

# %%
# !cat titanic.csv
# Out:
# Survived,Pclass,Name,Sex,Age,Siblings/Spouses Aboard,Parents/Children Aboard,Fare
# 0,3,Mr. Owen Harris Braund,male,22,1,0,7.25
# 1,1,Mrs. John Bradley (Florence Briggs Thayer) Cumings,female,38,1,0,71.2833
# 1,3,Miss. Laina Heikkinen,female,26,0,0,7.925
# 1,1,Mrs. Jacques Heath (Lily May Peel) Futrelle,female,35,1,0,53.1
# 0,3,Mr. William Henry Allen,male,35,0,0,8.05
# 0,3,Mr. James Moran,male,27,0,0,8.4583
# 0,1,Mr. Timothy J McCarthy,male,54,0,0,51.8625
# 0,3,Master. Gosta Leonard Palsson,male,2,3,1,21.075
# 1,3,Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson,female,27,0,2,11.1333
# 1,2,Mrs. Nicholas (Adele Achem) Nasser,female,14,1,0,30.0708
# 1,3,Miss. Marguerite Rut Sandstrom,female,4,1,1,16.7
# 1,1,Miss. Elizabeth Bonnell,female,58,0,0,26.55
# 0,3,Mr. William Henry Saundercock,male,20,0,0,8.05
# 0,3,Mr. Anders Johan Andersson,male,39,1,5,31.275
# 0,3,Miss. Hulda Amanda Adolfina Vestrom,female,14,0,0,7.8542
# 1,2,Mrs. (Mary D Kingcome) Hewlett,female,55,0,0,16
# ...

# %%
df = pd.read_csv('titanic.csv')

# %%
df.shape
# Out:
# (887, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
# eliminamos la columna Name que no nos sirve para el analisis
df = df.drop('Name',axis=1)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  Siblings/Spouses Aboard  \
# 0         0       3    male  22.0                        1
# 1         1       1  female  38.0                        1
# 2         1       3  female  26.0                        0
# 3         1       1  female  35.0                        1
# 4         0       3    male  35.0                        0
#
#    Parents/Children Aboard     Fare
# 0                        0   7.2500
# 1                        0  71.2833
# 2                        0   7.9250
# 3                        0  53.1000
# 4                        0   8.0500

# %%
# Cambiamos los nombres de las columnas por su traduccion al castellano
lista = 'sobrevive clase sexo edad familiares hijos tarifa'
df.columns = lista.split()

# %%
df.head()
# Out:
#    sobrevive  clase    sexo  edad  familiares  hijos   tarifa
# 0          0      3    male  22.0           1      0   7.2500
# 1          1      1  female  38.0           1      0  71.2833
# 2          1      3  female  26.0           0      0   7.9250
# 3          1      1  female  35.0           1      0  53.1000
# 4          0      3    male  35.0           0      0   8.0500

# %%
df.tail()
# Out:
#      sobrevive  clase    sexo  edad  familiares  hijos  tarifa
# 882          0      2    male  27.0           0      0   13.00
# 883          1      1  female  19.0           0      0   30.00
# 884          0      3  female   7.0           1      2   23.45
# 885          1      1    male  26.0           0      0   30.00
# 886          0      3    male  32.0           0      0    7.75

# %%
new_index = [element for element in range(1,df.shape[0],1)]
df = df.reindex(new_index)

# %%
df.head()
# Out:
#    sobrevive  clase    sexo  edad  familiares  hijos   tarifa
# 1          1      1  female  38.0           1      0  71.2833
# 2          1      3  female  26.0           0      0   7.9250
# 3          1      1  female  35.0           1      0  53.1000
# 4          0      3    male  35.0           0      0   8.0500
# 5          0      3    male  27.0           0      0   8.4583

# %%
# La variable sexo es de tipo string y hay que pasarla a numerica

# %%
df['sexo_bin'] = df.sexo == 'female'

# %%
df.head()
# Out:
#    sobrevive  clase    sexo  edad  familiares  hijos   tarifa  sexo_bin
# 1          1      1  female  38.0           1      0  71.2833      True
# 2          1      3  female  26.0           0      0   7.9250      True
# 3          1      1  female  35.0           1      0  53.1000      True
# 4          0      3    male  35.0           0      0   8.0500     False
# 5          0      3    male  27.0           0      0   8.4583     False

# %%
df['sexo_b']=df['sexo_bin'].astype('int',copy=True)

# %%
df.head()
# Out:
#    sobrevive  clase    sexo  edad  familiares  hijos   tarifa  sexo_bin  \
# 1          1      1  female  38.0           1      0  71.2833      True
# 2          1      3  female  26.0           0      0   7.9250      True
# 3          1      1  female  35.0           1      0  53.1000      True
# 4          0      3    male  35.0           0      0   8.0500     False
# 5          0      3    male  27.0           0      0   8.4583     False
#
#    sexo_b
# 1       1
# 2       1
# 3       1
# 4       0
# 5       0

# %%
#eliminamos la columna sexo y sexo_bin

# %%
df = df.drop(['sexo','sexo_bin'],axis=1)

# %%
# renombramos la columna sexo_b

# %%
df.rename({'sexo_b':'sexo'},axis=1,inplace=True)

# %%
df.head()
# Out:
#    sobrevive  clase  edad  familiares  hijos   tarifa  sexo
# 1          1      1  38.0           1      0  71.2833     1
# 2          1      3  26.0           0      0   7.9250     1
# 3          1      1  35.0           1      0  53.1000     1
# 4          0      3  35.0           0      0   8.0500     0
# 5          0      3  27.0           0      0   8.4583     0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 886 entries, 1 to 886
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sobrevive   886 non-null    int64
#  1   clase       886 non-null    int64
#  2   edad        886 non-null    float64
#  3   familiares  886 non-null    int64
#  4   hijos       886 non-null    int64
#  5   tarifa      886 non-null    float64
#  6   sexo        886 non-null    int64
# dtypes: float64(2), int64(5)
# memory usage: 55.4 KB

# %%
#vemos como es la distribucion por sexos
df.groupby('sexo').mean()
# Out:
#       sobrevive     clase       edad  familiares     hijos     tarifa
# sexo
# 0      0.190559  2.384615  30.446101    0.431818  0.237762  25.666075
# 1      0.742038  2.159236  27.719745    0.694268  0.649682  44.479818

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.bar(df.sexo,df.index)
# Out:
# <BarContainer object of 886 artists>
